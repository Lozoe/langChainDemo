# %% [markdown]
# from langchain_core.prompts import PromptTemplate
# from langchain_community.llms import Tongyi  # 导入通义千问Tongyi模型
# import dashscope
# import os
#
# # 默认加载.env中的环境变量
# from dotenv import load_dotenv, find_dotenv
# load_dotenv(find_dotenv())
#
# # 从环境变量获取 dashscope 的 API Key
# api_key = os.getenv('DASHSCOPE_API_KEY')
# dashscope.api_key = api_key
#
# # 加载 Tongyi 模型
# llm = Tongyi(model_name="qwen-turbo", dashscope_api_key=api_key)
#
# # 创建Prompt Template
# prompt = PromptTemplate(
#     input_variables=["product"],
#     template="What is a good name for a company that makes {product}?",
# )
#
# # 新推荐用法：将 prompt 和 llm 组合成一个"可运行序列"
# chain = prompt | llm
#
# # 使用 invoke 方法传入输入
# result1 = chain.invoke({"product": "colorful socks"})
# print(result1)

# %%
result2 = chain.invoke({"product": "广告设计"})
print(result2)
# Out:
# Here are several strong, memorable, and culturally appropriate English name suggestions for a company specializing in **广告设计 (advertising design)** — balancing creativity, professionalism, and market appeal (especially for bilingual or international clients):
#
# ### Top Recommendations:
# 1. **Lumina Studio**
#    *Why it works:* “Lumina” evokes light, clarity, and impact — essential for compelling ads. Short, elegant, globally pronounceable, and subtly suggests *illuminating* brands. Works well in both English and Chinese contexts (sounds refined, not literal).
#
# 2. **Verve Creative**
#    *Why it works:* “Verve” means energy, spirit, and flair — perfectly capturing the dynamism of great advertising design. Professional yet vibrant; easy to trademark and brand.
#
# 3. **Astra AdCraft**
#    *Why it works:* “Astra” (Latin for “stars”) conveys aspiration, visibility, and standout results; “AdCraft” clearly signals expertise in advertising *craftsmanship*. Modern, tech-adjacent but human-centered.
#
# 4. **Nexus Visual Co.**
#    *Why it works:* “Nexus” implies connection — between brand and audience, idea and execution. “Visual” grounds it in design; clean, trustworthy, and scalable beyond just ads (e.g., branding, digital, print).
#
# 5. **Hui Design Group** (慧设计集团)
#    *Why it works:* “Hui” (Chinese: 慧) means wisdom, insight, and intelligence — reflecting strategic, thoughtful ad design. Pronounced “hway”, it’s short, meaningful, culturally rooted, and easily localized (e.g., Hui Design | 慧设计). Ideal if targeting Chinese-speaking markets or emphasizing East-West synergy.
#
# ### Bonus (Playful & Memorable):
# - **Pixel & Pulse** — Suggests digital precision + human resonance. Great for modern, media-savvy brands.
# - **Chroma Lab** — “Chroma” = color/vibrancy; “Lab” implies innovation and experimentation. Stylish and design-forward.
#
# ### Naming Tips for Your Context:
# - ✅ **Avoid direct translations** like “AdDesign Co.” — they sound generic and lack memorability.
# - ✅ **Prioritize names that are easy to spell, say, and search** — especially important for SEO and word-of-mouth.
# - ✅ **Check domain & trademark availability** (e.g., lumina.studio, vervecreative.com).
# - ✅ **Test with your target audience** — e.g., does “Hui Design” resonate with clients in Shanghai? Does “Lumina” feel premium to global startups?
#
# Would you like help with:
# 🔹 A Chinese name (with English transliteration & meaning)?
# 🔹 Tagline ideas to match one of these names?
# 🔹 Logo concept or brand voice guidance?
#
# Happy to refine based on your brand personality (e.g., bold & disruptive vs. elegant & strategic) or market focus (e.g., local SMEs in Guangzhou vs. global tech clients).

# %% [markdown]
# # 标题一

# %% [markdown]
# ## 标题二
